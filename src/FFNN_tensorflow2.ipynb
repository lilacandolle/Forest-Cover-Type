# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_covtype
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# load dataset
X, y = fetch_covtype(return_X_y=True)

# create dataframe
feature_names = ['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology', 'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways', 
                 'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm', 'Horizontal_Distance_To_Fire_Points', 'Wilderness_Area1', 'Wilderness_Area2', 
                'Wilderness_Area3', 'Wilderness_Area4', 'Soil_Type1', 'Soil_Type2', 'Soil_Type3', 'Soil_Type4', 'Soil_Type5', 'Soil_Type6', 'Soil_Type7',
                'Soil_Type8', 'Soil_Type9', 'Soil_Type10', 'Soil_Type11', 'Soil_Type12', 'Soil_Type13', 'Soil_Type14', 'Soil_Type15', 'Soil_Type16', 
                 'Soil_Type17', 'Soil_Type18', 'Soil_Type19', 'Soil_Type20', 'Soil_Type21', 'Soil_Type22', 'Soil_Type23', 'Soil_Type24', 'Soil_Type25', 
                 'Soil_Type26', 'Soil_Type27', 'Soil_Type28', 'Soil_Type29', 'Soil_Type30', 'Soil_Type31', 'Soil_Type32', 'Soil_Type33', 'Soil_Type34', 
                 'Soil_Type35', 'Soil_Type36', 'Soil_Type37', 'Soil_Type38', 'Soil_Type39', 'Soil_Type40']

# Making a DataFrame
covtype_df = pd.DataFrame(X, columns=feature_names)
covtype_df['Cover_Type'] = y

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#set y values to 0-7
y_train = y_train - 1
y_test = y_test - 1

# %%
#FFNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD


#define RELU function as the activation function for the hidden layers
#use softmax function for the output layer
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[X_train.shape[1]]),
    layers.Dense(120, activation='relu'),
    layers.Dense(120, activation='relu'),
    layers.Dense(120, activation='relu'),
    layers.Dense(7, activation='softmax')
])

#compile the model
optimizer = Adam(learning_rate=10e-5)

model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
)
# Out:
# 2023-12-18 21:34:17.349578: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-18 21:34:20.554070: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#fit the model
model_fitting = model.fit(
    X_train, y_train,
    validation_data = (X_test, y_test),
    verbose=1, epochs=60)
# Out:
# Epoch 1/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 1.7529 - accuracy: 0.5817 - val_loss: 1.0578 - val_accuracy: 0.6434
# Epoch 2/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.9082 - accuracy: 0.6567 - val_loss: 0.7219 - val_accuracy: 0.7025
# Epoch 3/60
# 12710/12710 [==============================] - 16s 1ms/step - loss: 0.7462 - accuracy: 0.6934 - val_loss: 0.7059 - val_accuracy: 0.7060
# Epoch 4/60
# 12710/12710 [==============================] - 16s 1ms/step - loss: 0.6574 - accuracy: 0.7220 - val_loss: 0.6128 - val_accuracy: 0.7387
# Epoch 5/60
# 12710/12710 [==============================] - 18s 1ms/step - loss: 0.6012 - accuracy: 0.7436 - val_loss: 0.6330 - val_accuracy: 0.7335
# Epoch 6/60
# 12710/12710 [==============================] - 17s 1ms/step - loss: 0.5626 - accuracy: 0.7591 - val_loss: 0.5601 - val_accuracy: 0.7595
# Epoch 7/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.5332 - accuracy: 0.7714 - val_loss: 0.5168 - val_accuracy: 0.7724
# Epoch 8/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.5103 - accuracy: 0.7810 - val_loss: 0.5057 - val_accuracy: 0.7817
# Epoch 9/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.4887 - accuracy: 0.7902 - val_loss: 0.4654 - val_accuracy: 0.7981
# Epoch 10/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.4724 - accuracy: 0.7975 - val_loss: 0.4621 - val_accuracy: 0.8016
# Epoch 11/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.4560 - accuracy: 0.8047 - val_loss: 0.4501 - val_accuracy: 0.8062
# Epoch 12/60
# 12710/12710 [==============================] - 16s 1ms/step - loss: 0.4437 - accuracy: 0.8103 - val_loss: 0.4305 - val_accuracy: 0.8158
# Epoch 13/60
# 12710/12710 [==============================] - 16s 1ms/step - loss: 0.4297 - accuracy: 0.8167 - val_loss: 0.4578 - val_accuracy: 0.7979
# Epoch 14/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.4180 - accuracy: 0.8220 - val_loss: 0.4213 - val_accuracy: 0.8220
# Epoch 15/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.4081 - accuracy: 0.8270 - val_loss: 0.4064 - val_accuracy: 0.8286
# Epoch 16/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.3988 - accuracy: 0.8311 - val_loss: 0.3949 - val_accuracy: 0.8349
# Epoch 17/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.3891 - accuracy: 0.8359 - val_loss: 0.3982 - val_accuracy: 0.8322
# Epoch 18/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.3806 - accuracy: 0.8389 - val_loss: 0.3789 - val_accuracy: 0.8408
# Epoch 19/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.3739 - accuracy: 0.8422 - val_loss: 0.3660 - val_accuracy: 0.8487
# Epoch 20/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.3670 - accuracy: 0.8452 - val_loss: 0.3634 - val_accuracy: 0.8489
# Epoch 21/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.3591 - accuracy: 0.8490 - val_loss: 0.3654 - val_accuracy: 0.8464
# Epoch 22/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.3518 - accuracy: 0.8521 - val_loss: 0.3561 - val_accuracy: 0.8519
# Epoch 23/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.3460 - accuracy: 0.8544 - val_loss: 0.3567 - val_accuracy: 0.8520
# Epoch 24/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.3407 - accuracy: 0.8568 - val_loss: 0.3600 - val_accuracy: 0.8472
# Epoch 25/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.3353 - accuracy: 0.8594 - val_loss: 0.3432 - val_accuracy: 0.8589
# Epoch 26/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.3304 - accuracy: 0.8620 - val_loss: 0.3407 - val_accuracy: 0.8565
# Epoch 27/60
# 12710/12710 [==============================] - 16s 1ms/step - loss: 0.3252 - accuracy: 0.8638 - val_loss: 0.3624 - val_accuracy: 0.8497
# Epoch 28/60
# 12710/12710 [==============================] - 19s 1ms/step - loss: 0.3205 - accuracy: 0.8660 - val_loss: 0.3297 - val_accuracy: 0.8622
# Epoch 29/60
# 12710/12710 [==============================] - 16s 1ms/step - loss: 0.3158 - accuracy: 0.8682 - val_loss: 0.3231 - val_accuracy: 0.8654
# Epoch 30/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.3120 - accuracy: 0.8696 - val_loss: 0.3262 - val_accuracy: 0.8654
# Epoch 31/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.3087 - accuracy: 0.8714 - val_loss: 0.3229 - val_accuracy: 0.8639
# Epoch 32/60
# 12710/12710 [==============================] - 16s 1ms/step - loss: 0.3032 - accuracy: 0.8739 - val_loss: 0.3256 - val_accuracy: 0.8625
# Epoch 33/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2999 - accuracy: 0.8753 - val_loss: 0.3113 - val_accuracy: 0.8712
# Epoch 34/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.2957 - accuracy: 0.8769 - val_loss: 0.3114 - val_accuracy: 0.8720
# Epoch 35/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.2933 - accuracy: 0.8781 - val_loss: 0.3143 - val_accuracy: 0.8720
# Epoch 36/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2892 - accuracy: 0.8798 - val_loss: 0.2995 - val_accuracy: 0.8777
# Epoch 37/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2880 - accuracy: 0.8809 - val_loss: 0.2994 - val_accuracy: 0.8763
# Epoch 38/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2845 - accuracy: 0.8821 - val_loss: 0.2934 - val_accuracy: 0.8796
# Epoch 39/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.2816 - accuracy: 0.8832 - val_loss: 0.3475 - val_accuracy: 0.8558
# Epoch 40/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.2781 - accuracy: 0.8852 - val_loss: 0.2886 - val_accuracy: 0.8826
# Epoch 41/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2766 - accuracy: 0.8857 - val_loss: 0.3116 - val_accuracy: 0.8693
# Epoch 42/60
# 12710/12710 [==============================] - 16s 1ms/step - loss: 0.2723 - accuracy: 0.8880 - val_loss: 0.2905 - val_accuracy: 0.8809
# Epoch 43/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2709 - accuracy: 0.8885 - val_loss: 0.2789 - val_accuracy: 0.8872
# Epoch 44/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2670 - accuracy: 0.8897 - val_loss: 0.2795 - val_accuracy: 0.8868
# Epoch 45/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2657 - accuracy: 0.8902 - val_loss: 0.2775 - val_accuracy: 0.8872
# Epoch 46/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2630 - accuracy: 0.8918 - val_loss: 0.2933 - val_accuracy: 0.8809
# Epoch 47/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2607 - accuracy: 0.8934 - val_loss: 0.2589 - val_accuracy: 0.8950
# Epoch 48/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.2590 - accuracy: 0.8933 - val_loss: 0.2722 - val_accuracy: 0.8878
# Epoch 49/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.2571 - accuracy: 0.8944 - val_loss: 0.2743 - val_accuracy: 0.8882
# Epoch 50/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2549 - accuracy: 0.8957 - val_loss: 0.2680 - val_accuracy: 0.8917
# Epoch 51/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2517 - accuracy: 0.8969 - val_loss: 0.2873 - val_accuracy: 0.8854
# Epoch 52/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.2502 - accuracy: 0.8975 - val_loss: 0.2675 - val_accuracy: 0.8922
# Epoch 53/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.2481 - accuracy: 0.8979 - val_loss: 0.2716 - val_accuracy: 0.8887
# Epoch 54/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.2472 - accuracy: 0.8992 - val_loss: 0.2864 - val_accuracy: 0.8816
# Epoch 55/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2447 - accuracy: 0.8999 - val_loss: 0.2694 - val_accuracy: 0.8912
# Epoch 56/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2430 - accuracy: 0.9009 - val_loss: 0.2498 - val_accuracy: 0.8999
# Epoch 57/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.2416 - accuracy: 0.9014 - val_loss: 0.2581 - val_accuracy: 0.8973
# Epoch 58/60
# 12710/12710 [==============================] - 14s 1ms/step - loss: 0.2402 - accuracy: 0.9025 - val_loss: 0.2509 - val_accuracy: 0.9000
# Epoch 59/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2374 - accuracy: 0.9033 - val_loss: 0.2536 - val_accuracy: 0.8983
# Epoch 60/60
# 12710/12710 [==============================] - 15s 1ms/step - loss: 0.2359 - accuracy: 0.9040 - val_loss: 0.2445 - val_accuracy: 0.9025

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(model_fitting.history['accuracy'])
plt.plot(model_fitting.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(model_fitting.history['loss'])
plt.plot(model_fitting.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Cross-entropy (loss function)')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# modifying code the code found in the documentation of the Python library scikit-learn https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html
# plot of the ROC curve for each class against the others

from sklearn.metrics import RocCurveDisplay
from itertools import cycle
import matplotlib.cm as cm

y_predict = model.predict(X_test)
n_classes = (np.unique(y_test)).shape[0]
y_test_bin = keras.utils.to_categorical(y_test, n_classes)

fig, ax = plt.subplots()
cmap = cm.get_cmap('viridis')
colors = [cmap(i) for i in np.linspace(0, 1, n_classes)]
for class_id, color in zip(range(n_classes), colors):
    RocCurveDisplay.from_predictions(
        y_test_bin[:, class_id],
        y_predict[:, class_id],
        name=f"ROC curve for class {class_id}",
        color=color,
        ax = ax,
        plot_chance_level=(class_id == 6),
    )
plt.show()
# Out:
# 5447/5447 [==============================] - 3s 543us/step
# /var/folders/_t/pzbtlqfs06q4gkr88b12hv9r0000gn/T/ipykernel_17535/2699802169.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis')

# %%
#using the code from the lecture of Applied Data and Machine Learning, Week45, Morten Hjorth-Jensen https://compphysics.github.io/MachineLearning/doc/LectureNotes/_build/html/week45.html
from sklearn.metrics import confusion_matrix
import scikitplot as skplt

y_pred_classes = np.argmax(y_predict, axis=1)

skplt.metrics.plot_confusion_matrix(y_test, y_pred_classes, normalize=True)
plt.show()
confusion_matrix = confusion_matrix(y_test, y_pred_classes)

print(confusion_matrix)
# Out:
# [[55011  7873     3     0    50     8   611]
#  [ 4246 79895   346     1   275   228    87]
#  [    4   251  9857   102     5   419     0]
#  [    0     4    73   692     0    26     0]
#  [   83   773    92     0  1974    19     0]
#  [   28   261   606    56     5  4271     0]
#  [  370    96     0     0     1     0  5602]]

# %%
skplt.metrics.plot_roc(y_test, y_predict)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
